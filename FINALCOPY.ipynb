# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nRowsRead = 120

dfx=pd.read_excel('II SEM.xlsx', nrows = nRowsRead)
dfx.dataframeName = 'II SEM.csv'
nRow, nCol = dfx.shape
dfx.shape
# Out:
# (120, 12)

# %%
dfx
# Out:
#      Roll No. EN M2 CHEM PPS WS LAB EITK ENG LAB CHEM LAB PPS LAB EVS  CGPA
# 0           1  C  F    D   C     A     B       A        S       S   B   NaN
# 1           2  B  A    B   B      S    S       S        A       S   A  8.79
# 2           3  A  B    B   A      S    B       S        S       S   B  8.92
# 3           4  C  C    D   B     A     D       A        S       S   B  7.74
# 4           5  C  C    C   C      S    A       S        S       S   A  8.21
# ..        ... .. ..  ...  ..    ...  ...     ...      ...     ...  ..   ...
# 115       116  B  D    F   F      A    D       A        A       A   E   NaN
# 116       117  B  D    C   C      A    C       A        A       A   A  7.56
# 117       118  B  F    E   E      A    D       B        B       B   E   NaN
# 118       119  D  E    D   D      S    B       A        S       S   C  7.08
# 119       120  D  F    F   F      A    C       B        B       C   F   NaN
#
# [120 rows x 12 columns]

# %%
dfx.isnull().sum()
# Out:
# Roll No.     0
# EN           1
# M2           1
# CHEM         1
# PPS          1
# WS LAB       1
# EITK         1
# ENG LAB      1
# CHEM LAB     1
# PPS LAB      1
# EVS          1
# CGPA        65
# dtype: int64

# %%
passedx=dfx[~dfx['CGPA'].isnull()]
passedx
# Out:
#      Roll No. EN M2 CHEM PPS WS LAB EITK ENG LAB CHEM LAB PPS LAB EVS  CGPA
# 1           2  B  A    B   B      S    S       S        A       S   A  8.79
# 2           3  A  B    B   A      S    B       S        S       S   B  8.92
# 3           4  C  C    D   B     A     D       A        S       S   B  7.74
# 4           5  C  C    C   C      S    A       S        S       S   A  8.21
# 5           6  B  D    C   D     A     B       S        S       A   B  7.54
# 6           7  B  D    D   E      S    A       S        S       S   B  7.38
# 7           8  B  C    D   D      S    C       S        S       B   B  7.64
# 10         11  A  C    D   D     A     B       S        S       S   B  7.64
# 11         12  B  D    D   C      B    C       A        A       B   A  7.15
# 12         13  C  D    D   A      E    D       A        A       A   C  6.45
# 15         16  A  B    C   C      S    B       A        S       S   B  8.36
# ...

# %%
dfx.dropna(subset=['EN'], inplace=True)

# %%
dfx
# Out:
#      Roll No. EN M2 CHEM PPS WS LAB EITK ENG LAB CHEM LAB PPS LAB EVS  CGPA
# 0           1  C  F    D   C     A     B       A        S       S   B   NaN
# 1           2  B  A    B   B      S    S       S        A       S   A  8.79
# 2           3  A  B    B   A      S    B       S        S       S   B  8.92
# 3           4  C  C    D   B     A     D       A        S       S   B  7.74
# 4           5  C  C    C   C      S    A       S        S       S   A  8.21
# ..        ... .. ..  ...  ..    ...  ...     ...      ...     ...  ..   ...
# 115       116  B  D    F   F      A    D       A        A       A   E   NaN
# 116       117  B  D    C   C      A    C       A        A       A   A  7.56
# 117       118  B  F    E   E      A    D       B        B       B   E   NaN
# 118       119  D  E    D   D      S    B       A        S       S   C  7.08
# 119       120  D  F    F   F      A    C       B        B       C   F   NaN
#
# [119 rows x 12 columns]

# %%
totalx= dfx.set_index('Roll No.')
totalx
# Out:
#          EN M2 CHEM PPS WS LAB EITK ENG LAB CHEM LAB PPS LAB EVS  CGPA
# Roll No.
# 1         C  F    D   C     A     B       A        S       S   B   NaN
# 2         B  A    B   B      S    S       S        A       S   A  8.79
# 3         A  B    B   A      S    B       S        S       S   B  8.92
# 4         C  C    D   B     A     D       A        S       S   B  7.74
# 5         C  C    C   C      S    A       S        S       S   A  8.21
# ...      .. ..  ...  ..    ...  ...     ...      ...     ...  ..   ...
# 116       B  D    F   F      A    D       A        A       A   E   NaN
# 117       B  D    C   C      A    C       A        A       A   A  7.56
# 118       B  F    E   E      A    D       B        B       B   E   NaN
# 119       D  E    D   D      S    B       A        S       S   C  7.08
# 120       D  F    F   F      A    C       B        B       C   F   NaN
#
# [119 rows x 11 columns]

# %%
sns.displot(dfx['CGPA'])

# %%
failedx = dfx[dfx['CGPA'].isna()]
failedx
# Out:
#      Roll No. EN M2 CHEM PPS WS LAB EITK ENG LAB CHEM LAB PPS LAB EVS  CGPA
# 0           1  C  F    D   C     A     B       A        S       S   B   NaN
# 8           9  C  F    E   B      B    A       A        A       B   B   NaN
# 9          10  C  F    E   F      C    C       B        A       C   C   NaN
# 13         14  C  F    D   F     A     C       A        A       A   C   NaN
# 14         15  B  F    E   E      B    D       A        B       C   D   NaN
# ..        ... .. ..  ...  ..    ...  ...     ...      ...     ...  ..   ...
# 113       114  D  F    F   F      A    E       B        B       C   E   NaN
# 114       115  E  F    F   F      A    F       A        B       A   D   NaN
# 115       116  B  D    F   F      A    D       A        A       A   E   NaN
# 117       118  B  F    E   E      A    D       B        B       B   E   NaN
# 119       120  D  F    F   F      A    C       B        B       C   F   NaN
#
# [64 rows x 12 columns]

# %%
len(dfx[(dfx['CGPA'].isna())])
# Out:
# 64

# %%
len(dfx[~dfx['CGPA'].isnull()])
# Out:
# 55

# %%
len(totalx)
# Out:
# 119

# %%
pass_percentage_x = int((len(dfx[~dfx['CGPA'].isnull()])/len(totalx))*100)
pass_percentage_x
# Out:
# 46

# %%
fail_percentage_x = int((len(dfx[(dfx['CGPA'].isna())])/len(totalx))*100)
fail_percentage_x
# Out:
# 53

# %%
f2x= (dfx == 'F')
f2x
# Out:
#      Roll No.     EN     M2   CHEM    PPS  WS LAB   EITK  ENG LAB  CHEM LAB  \
# 0       False  False   True  False  False   False  False    False     False
# 1       False  False  False  False  False   False  False    False     False
# 2       False  False  False  False  False   False  False    False     False
# 3       False  False  False  False  False   False  False    False     False
# 4       False  False  False  False  False   False  False    False     False
# ..        ...    ...    ...    ...    ...     ...    ...      ...       ...
# 115     False  False  False   True   True   False  False    False     False
# 116     False  False  False  False  False   False  False    False     False
# 117     False  False   True  False  False   False  False    False     False
# 118     False  False  False  False  False   False  False    False     False
# 119     False  False   True   True   True   False  False    False     False
#
#      PPS LAB    EVS   CGPA
# 0      False  False  False
# ...

# %%
# Get count of True values in column 'C'
f_eng = f2x['EN'].value_counts() [False]
f_m2 = f2x['M2'].value_counts() [False]
f_chem = f2x['CHEM'].value_counts() [False]
f_pps = f2x['PPS'].value_counts() [False]
f_ws = f2x['WS LAB'].value_counts() [False]
f_eitk = f2x['EITK'].value_counts() [False]
f_enl = f2x['ENG LAB'].value_counts() [False]
f_chl = f2x['CHEM LAB'].value_counts() [False]
f_ppl = f2x['PPS LAB'].value_counts() [False]
f_evs = f2x['EVS'].value_counts() [False]

f_eng = 119 - f_eng
f_m2 = 119 - f_m2
f_chem = 119 - f_chem
f_pps = 119 - f_pps
f_ws = 119 - f_ws
f_eitk = 119 - f_eitk
f_enl = 119 - f_enl
f_chl = 119 - f_chl
f_ppl = 119 - f_ppl
f_evs = 119 - f_evs

print('Count of True values in Column  D : ', f_eng)
print('Count of True values in Column  D : ', f_m2)
print('Count of True values in Column  D : ', f_chem)
print('Count of True values in Column  D : ', f_pps)
print('Count of True values in Column  D : ', f_ws)
print('Count of True values in Column  D : ', f_eitk)
print('Count of True values in Column  D : ', f_enl)
print('Count of True values in Column  D : ', f_chl)
print('Count of True values in Column  D : ', f_ppl)
print('Count of True values in Column  D : ', f_evs)
# Out:
# Count of True values in Column  D :  0
# Count of True values in Column  D :  44
# Count of True values in Column  D :  27
# Count of True values in Column  D :  45
# Count of True values in Column  D :  0
# Count of True values in Column  D :  3
# Count of True values in Column  D :  0
# Count of True values in Column  D :  0
# Count of True values in Column  D :  0
# Count of True values in Column  D :  7

# %%
#PASSED SUBJECTS IN SEM 2
dfx_col = ['EN','M2','CHEM','PPS','WS LAB','EITK','ENG LAB','CHEM LAB','PPS LAB','EVS']
passs = [f_eng, f_m2, f_chem, f_pps, f_ws , f_eitk, f_enl, f_chl, f_ppl, f_evs]
fig, az = plt.subplots(figsize=(10, 5))

second=sns.barplot(dfx_col,passs,ax=az)
second.set(xlabel ="Subjects", ylabel = "No. of students failed", title ='SEM II SUBJECT WISE - NUMBER OF STUDENTS FAILED')

plt.show()
# Out:
# C:\Users\Fouziyah Maheen\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
nRowsRead = 132

dfy=pd.read_excel('sem4.xlsx', nrows = nRowsRead)
dfy.dataframeName = 'sem4.csv'
nRow, nCol = dfy.shape
dfy.shape
# Out:
# (131, 10)

# %%
dfy
# Out:
#      Roll No. EMI AEC EMTL PLIC COA AEC LAB PLIC LAB SS  CGPA
# 0           1   A   C    A    D   C       A        A  B  7.81
# 1           2   A   A    S    S   A       S        S  S  9.57
# 2           3   D   C    A    F   C       A        A  C   NaN
# 3           4   B   S    B    C   A       S        S  A  8.67
# 4           5   A   S    B    D   A       S        A  A  8.62
# ..        ...  ..  ..  ...  ...  ..     ...      ... ..   ...
# 126       308   C   F    C    D   C       S        S  D   NaN
# 127       309   S   C    A    B   C       A        S  C  8.10
# 128       310   D   F    C    F   D       A        B  F   NaN
# 129       311   D   F    D    F   D       A        B  F   NaN
# 130       312   D   F    E    F   D       B        B  F   NaN
#
# [131 rows x 10 columns]

# %%
dfy.isnull().sum()
# Out:
# Roll No.     0
# EMI          0
# AEC          0
# EMTL         0
# PLIC         0
# COA          0
# AEC LAB      0
# PLIC LAB     0
# SS           0
# CGPA        98
# dtype: int64

# %%
passedy=dfy[~dfy['CGPA'].isnull()]
passedy
# Out:
#      Roll No. EMI AEC EMTL PLIC COA AEC LAB PLIC LAB SS  CGPA
# 0           1   A   C    A    D   C       A        A  B  7.81
# 1           2   A   A    S    S   A       S        S  S  9.57
# 3           4   B   S    B    C   A       S        S  A  8.67
# 4           5   A   S    B    D   A       S        A  A  8.62
# 5           6   E   C    A    D   B       A        S  B  7.43
# 6           7   C   B    B    D   E       B        A  B  7.19
# 7           8   A   B    A    B   A       A        A  B  8.52
# 11         12   C   C    B    D   E       B        A  D  6.67
# 12         13   C   C    B    D   E       B        A  D  6.67
# 14         15   C   D    B    D   C       B        S  C  7.05
# 21         22   A   C    B    C   B       A        A  A  8.14
# 27         28   D   D    D    D   C       A        C  C  6.52
# 30         31   A   B    A    C   B       S        S  A  8.52
# 50         51   C   C    B    D   A       A        B  B  7.62
# ...

# %%
totaly= dfy.set_index('Roll No.')
totaly
# Out:
#          EMI AEC EMTL PLIC COA AEC LAB PLIC LAB SS  CGPA
# Roll No.
# 1          A   C    A    D   C       A        A  B  7.81
# 2          A   A    S    S   A       S        S  S  9.57
# 3          D   C    A    F   C       A        A  C   NaN
# 4          B   S    B    C   A       S        S  A  8.67
# 5          A   S    B    D   A       S        A  A  8.62
# ...       ..  ..  ...  ...  ..     ...      ... ..   ...
# 308        C   F    C    D   C       S        S  D   NaN
# 309        S   C    A    B   C       A        S  C  8.10
# 310        D   F    C    F   D       A        B  F   NaN
# 311        D   F    D    F   D       A        B  F   NaN
# 312        D   F    E    F   D       B        B  F   NaN
#
# [131 rows x 9 columns]

# %%
sns.displot(dfy['CGPA'])

# %%
failedy = dfy[dfy['CGPA'].isna()]
failedy
# Out:
#      Roll No. EMI AEC EMTL PLIC COA AEC LAB PLIC LAB SS  CGPA
# 2           3   D   C    A    F   C       A        A  C   NaN
# 8           9   C   C    D    F   F       B        A  C   NaN
# 9          10   C   F    A    F   D       A        A  C   NaN
# 10         11   C   D    B    F   B       A        A  D   NaN
# 13         14   D   D    C    F   C       B        C  D   NaN
# ..        ...  ..  ..  ...  ...  ..     ...      ... ..   ...
# 125       307   B   F    S    D   F       S        S  D   NaN
# 126       308   C   F    C    D   C       S        S  D   NaN
# 128       310   D   F    C    F   D       A        B  F   NaN
# 129       311   D   F    D    F   D       A        B  F   NaN
# 130       312   D   F    E    F   D       B        B  F   NaN
#
# [98 rows x 10 columns]

# %%
pass_percentage_y = int((len(dfy[~dfy['CGPA'].isnull()])/len(totaly))*100)
pass_percentage_y
# Out:
# 25

# %%
fail_percentage_y = int((len(dfy[(dfy['CGPA'].isna())])/len(totaly))*100)
fail_percentage_y
# Out:
# 74

# %%
f2y = (dfy == 'F')
f2y
# Out:
#      Roll No.    EMI    AEC   EMTL   PLIC    COA  AEC LAB  PLIC LAB     SS  \
# 0       False  False  False  False  False  False    False     False  False
# 1       False  False  False  False  False  False    False     False  False
# 2       False  False  False  False   True  False    False     False  False
# 3       False  False  False  False  False  False    False     False  False
# 4       False  False  False  False  False  False    False     False  False
# ..        ...    ...    ...    ...    ...    ...      ...       ...    ...
# 126     False  False   True  False  False  False    False     False  False
# 127     False  False  False  False  False  False    False     False  False
# 128     False  False   True  False   True  False    False     False   True
# 129     False  False   True  False   True  False    False     False   True
# 130     False  False   True  False   True  False    False     False   True
#
#       CGPA
# 0    False
# 1    False
# 2    False
# 3    False
# ...

# %%
# Get count of True values in column 'C'
f_EMI = f2y['EMI'].value_counts() [False]
f_AEC = f2y['AEC'].value_counts() [False]
f_EMTL = f2y['EMTL'].value_counts() [False]
f_PLIC = f2y['PLIC'].value_counts() [False]
f_COA = f2y['COA'].value_counts() [False]
f_AEC_LAB = f2y['AEC LAB'].value_counts() [False]
f_PLIC_LAB = f2y['PLIC LAB'].value_counts() [False]
f_SS = f2y['SS'].value_counts() [False]

emi = 131 - f_EMI
aec = 131 - f_AEC
emtl = 131 - f_EMTL
plic = 131 - f_PLIC
coa = 131 - f_COA
aec_lab = 131 - f_AEC_LAB
plic_lab = 131 - f_PLIC_LAB
ss = 131 - f_SS

print('Count of True values in Column  D : ', emi)
print('Count of True values in Column  D : ', aec)
print('Count of True values in Column  D : ', emtl)
print('Count of True values in Column  D : ', plic)
print('Count of True values in Column  D : ', coa)
print('Count of True values in Column  D : ', aec_lab)
print('Count of True values in Column  D : ', plic_lab)
print('Count of True values in Column  D : ', ss)
# Out:
# Count of True values in Column  D :  22
# Count of True values in Column  D :  55
# Count of True values in Column  D :  24
# Count of True values in Column  D :  75
# Count of True values in Column  D :  52
# Count of True values in Column  D :  12
# Count of True values in Column  D :  3
# Count of True values in Column  D :  59

# %%
#PASSED SUBJECTS IN SEM 2
dfy_col = ['EMI','AEC','EMTL','PLIC','COA','AEC LAB','PLIC LAB','SS']
passy = [emi, aec, emtl, plic, coa , aec_lab, plic_lab, ss]

fig, ay = plt.subplots(figsize=(10, 5))

fourth=sns.barplot(dfy_col,passy,ax=ay)
fourth.set(xlabel ="Subjects", ylabel = "No. of students failed", title ='SEM IV SUBJECT WISE - NUMBER OF STUDENTS FAILED')

plt.show()
# Out:
# C:\Users\Fouziyah Maheen\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
nRowsRead = 132

dfz=pd.read_excel('SEM VI.xlsx', nrows = nRowsRead)
dfz.dataframeName = 'SEM VI.csv'
nRow, nCol = dfz.shape
dfz.shape
# Out:
# (132, 11)

# %%
dfz
# Out:
#      Roll No. DSD DC DCCN LAB DSD LAB DCCN EMI CL DS IOT   GPA
# 0           1   C  C        S       S    B   B  B  E   B  7.50
# 1           2   C  C        A       S    C   B  C  D   C  7.23
# 2           3   E  D        S       D    D   C  C  D   D  6.41
# 3           4   D  D        S       S    C   D  C  D   C  6.73
# 4           5   D  B        S       S    B   B  S  D   C  7.59
# ..        ...  .. ..      ...     ...  ...  .. .. ..  ..   ...
# 127       308   C  B        A       S    C   B  S  D   A   NaN
# 128       309   C  C        S       S    C   C  A  A   B  7.77
# 129       310   B  B        A       S    A   A  S  S   A  8.95
# 130       311   E  D        C       A    B   B  B  B   B  7.32
# 131       312   F  E        B       A    E   F  C  F   E   NaN
#
# [132 rows x 11 columns]

# %%
dfz.isnull().sum()
# Out:
# Roll No.     0
# DSD          3
# DC           3
# DCCN LAB     3
# DSD LAB      3
# DCCN         3
# EMI          3
# CL           3
# DS           3
# IOT          3
# GPA         19
# dtype: int64

# %%
passedz=dfz[~dfz['GPA'].isnull()]
passedz
# Out:
#      Roll No. DSD DC DCCN LAB DSD LAB DCCN EMI CL DS IOT   GPA
# 0           1   C  C        S       S    B   B  B  E   B  7.50
# 1           2   C  C        A       S    C   B  C  D   C  7.23
# 2           3   E  D        S       D    D   C  C  D   D  6.41
# 3           4   D  D        S       S    C   D  C  D   C  6.73
# 4           5   D  B        S       S    B   B  S  D   C  7.59
# ..        ...  .. ..      ...     ...  ...  .. .. ..  ..   ...
# 125       306   B  A        S       S    B   B  S  C   B  8.27
# 126       307   E  C        A       S    B   C  S  B   B  7.55
# 128       309   C  C        S       S    C   C  A  A   B  7.77
# 129       310   B  B        A       S    A   A  S  S   A  8.95
# 130       311   E  D        C       A    B   B  B  B   B  7.32
#
# [113 rows x 11 columns]

# %%
dfz.dropna(subset=['DSD'], inplace=True)
dfz
# Out:
#      Roll No. DSD DC DCCN LAB DSD LAB DCCN EMI CL DS IOT   GPA
# 0           1   C  C        S       S    B   B  B  E   B  7.50
# 1           2   C  C        A       S    C   B  C  D   C  7.23
# 2           3   E  D        S       D    D   C  C  D   D  6.41
# 3           4   D  D        S       S    C   D  C  D   C  6.73
# 4           5   D  B        S       S    B   B  S  D   C  7.59
# ..        ...  .. ..      ...     ...  ...  .. .. ..  ..   ...
# 127       308   C  B        A       S    C   B  S  D   A   NaN
# 128       309   C  C        S       S    C   C  A  A   B  7.77
# 129       310   B  B        A       S    A   A  S  S   A  8.95
# 130       311   E  D        C       A    B   B  B  B   B  7.32
# 131       312   F  E        B       A    E   F  C  F   E   NaN
#
# [129 rows x 11 columns]

# %%
passedz=dfz[~dfz['GPA'].isnull()]
passedz
# Out:
#      Roll No. DSD DC DCCN LAB DSD LAB DCCN EMI CL DS IOT   GPA
# 0           1   C  C        S       S    B   B  B  E   B  7.50
# 1           2   C  C        A       S    C   B  C  D   C  7.23
# 2           3   E  D        S       D    D   C  C  D   D  6.41
# 3           4   D  D        S       S    C   D  C  D   C  6.73
# 4           5   D  B        S       S    B   B  S  D   C  7.59
# ..        ...  .. ..      ...     ...  ...  .. .. ..  ..   ...
# 125       306   B  A        S       S    B   B  S  C   B  8.27
# 126       307   E  C        A       S    B   C  S  B   B  7.55
# 128       309   C  C        S       S    C   C  A  A   B  7.77
# 129       310   B  B        A       S    A   A  S  S   A  8.95
# 130       311   E  D        C       A    B   B  B  B   B  7.32
#
# [113 rows x 11 columns]

# %%
totalz= dfz.set_index('Roll No.')
totalz
# Out:
#          DSD DC DCCN LAB DSD LAB DCCN EMI CL DS IOT   GPA
# Roll No.
# 1          C  C        S       S    B   B  B  E   B  7.50
# 2          C  C        A       S    C   B  C  D   C  7.23
# 3          E  D        S       D    D   C  C  D   D  6.41
# 4          D  D        S       S    C   D  C  D   C  6.73
# 5          D  B        S       S    B   B  S  D   C  7.59
# ...       .. ..      ...     ...  ...  .. .. ..  ..   ...
# 308        C  B        A       S    C   B  S  D   A   NaN
# 309        C  C        S       S    C   C  A  A   B  7.77
# 310        B  B        A       S    A   A  S  S   A  8.95
# 311        E  D        C       A    B   B  B  B   B  7.32
# 312        F  E        B       A    E   F  C  F   E   NaN
#
# [129 rows x 10 columns]

# %%
sns.displot(dfz['GPA'])

# %%
failedz = dfz[dfz['GPA'].isna()]
failedz
# Out:
#      Roll No. DSD DC DCCN LAB DSD LAB DCCN EMI CL DS IOT  GPA
# 21         22   F  C        S       B    D   F  B  B   C  NaN
# 25         26   F  E        S       B    C   E  B  D   D  NaN
# 28         29   F  D        B       A    E   E  C  C   E  NaN
# 33         34  AB  E        A       A    E   E  C  C   F  NaN
# 37         38   F  D        A       A    C   D  B  D   C  NaN
# 39         40   F  D        S       A    D   D  A  E   D  NaN
# 43         44   F  F        D       A    F   D  C  D   F  NaN
# 56         57   F  E        A       A    D   E  C  E   E  NaN
# 57         58   F  F        A       A    D   E  C  E   D  NaN
# 77         78   D  D        A       S    F   C  A  D   B  NaN
# 81         82  AB  D        A       A    D   D  B  C   D  NaN
# 94         95   F  E        B       A    F   D  B  B   E  NaN
# 102       103   F  F        B       B    F   D  C  D   D  NaN
# 117       118   F  D        C       A    D   F  B  F  AB  NaN
# ...

# %%
pass_percentage_z = int((len(dfz[~dfz['GPA'].isnull()])/len(totalz))*100)
pass_percentage_z
# Out:
# 87

# %%
fail_percentage_z = int((len(dfz[(dfz['GPA'].isna())])/len(totalz))*100)
fail_percentage_z
# Out:
# 12

# %%
f2z = (dfz == 'F')
f2z
# Out:
#      Roll No.    DSD     DC  DCCN LAB  DSD LAB   DCCN    EMI     CL     DS  \
# 0       False  False  False     False    False  False  False  False  False
# 1       False  False  False     False    False  False  False  False  False
# 2       False  False  False     False    False  False  False  False  False
# 3       False  False  False     False    False  False  False  False  False
# 4       False  False  False     False    False  False  False  False  False
# ..        ...    ...    ...       ...      ...    ...    ...    ...    ...
# 127     False  False  False     False    False  False  False  False  False
# 128     False  False  False     False    False  False  False  False  False
# 129     False  False  False     False    False  False  False  False  False
# 130     False  False  False     False    False  False  False  False  False
# 131     False   True  False     False    False  False   True  False   True
#
#        IOT    GPA
# 0    False  False
# 1    False  False
# ...

# %%
# Get count of True values in column 'C'
f_DSD = f2z['DSD'].value_counts() [False]
f_DC = f2z['DC'].value_counts() [False]
f_DCCN_LAB = f2z['DCCN LAB'].value_counts() [False]
f_DSD_LAB = f2z['DSD LAB'].value_counts() [False]
f_DCCN = f2z['DCCN'].value_counts() [False]
f_EMI = f2z['EMI'].value_counts() [False]
f_CL = f2z['CL'].value_counts() [False]
f_DS = f2z['DS'].value_counts() [False]
f_IOT = f2z['IOT'].value_counts() [False]

dsd=129-f_DSD
dc=129-f_DC
dccn_lab = 129-f_DCCN_LAB
dsd_lab = 129-f_DSD_LAB
dccn = 129 - f_DCCN
emi = 129-f_EMI
cl = 129- f_CL
ds =  129 - f_DS 
iot = 129 - f_IOT
print('Count of True values in Column  D : ', dsd)
print('Count of True values in Column  D : ', dc)
print('Count of True values in Column  D : ', dccn_lab)
print('Count of True values in Column  D : ', dsd_lab)
print('Count of True values in Column  D : ', dccn)
print('Count of True values in Column  D : ', emi)
print('Count of True values in Column  D : ', cl)
print('Count of True values in Column  D : ', ds)

print('Count of True values in Column  D : ', iot)
# Out:
# Count of True values in Column  D :  12
# Count of True values in Column  D :  3
# Count of True values in Column  D :  0
# Count of True values in Column  D :  0
# Count of True values in Column  D :  4
# Count of True values in Column  D :  3
# Count of True values in Column  D :  0
# Count of True values in Column  D :  2
# Count of True values in Column  D :  2

# %%
#PASSED SUBJECTS IN SEM 2
dfz_col = ['DSD','DC','DCCN LAB','DSD LAB','DCCN','EMI','CL','DS','IOT']
passz = [dsd,dc,dccn_lab,dsd_lab,dccn,emi,cl,ds,iot]
fig, ax = plt.subplots(figsize=(10, 5))

sixth=sns.barplot(dfz_col,passz,ax=ax)
sixth.set(xlabel ="Subjects", ylabel = "No. of students failed", title ='SEM VI SUBJECT WISE - NUMBER OF STUDENTS FAILED')

plt.show()
# Out:
# C:\Users\Fouziyah Maheen\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#PASSED SUBJECTS IN SEM 2
dfz_col = ['DSD','DC','DCCN LAB','DSD LAB','DCCN','EMI','CL','DS','IOT']
passz = [dsd,dc,dccn_lab,dsd_lab,dccn,emi,cl,ds,iot]
fig, ax = plt.subplots(figsize=(10, 5))

sixth=sns.barplot(dfz_col,passz,ax=ax)
sixth.set(xlabel ="Subjects", ylabel = "No. of students failed", title ='SEM VI SUBJECT WISE - NUMBER OF STUDENTS FAILED')

plt.show()
# Out:
# C:\Users\Fouziyah Maheen\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
passed=[pass_percentage_x, pass_percentage_y, pass_percentage_z]
failed = [fail_percentage_x,fail_percentage_y, fail_percentage_z]
  
X = ['SEM 2', 'SEM 4' , 'SEM 6']
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, passed, 0.4, label = 'PASSED')
plt.bar(X_axis + 0.2, failed, 0.4, label = 'failed')
  
plt.xticks(X_axis, X)
plt.xlabel("SEMESTER")
plt.ylabel("Number of Students")
plt.title("PASS&FAIL PERCENTAGE OF STUDENTS EVEN SEMS - 2022")
plt.legend()
plt.show()
